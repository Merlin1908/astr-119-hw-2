# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,2*np.pi,2*np.pi/1000)

# %%
x

# %%
x = np.linspace(0,2*np.pi,1000)

# %%
np.shape(x)

# %%
2*np.pi

# %% [markdown]
# I am about to plot Part A of homework 2 as follows

# %%
def func_a(x):
    return 5.5 *np.cos(2*x) + 5.5

# %%
plt.plot(x,y_a)
plt.xlim(0,2*np.pi)
plt.ylim(-1,10)
plt.xlabel('Time in ASTR/EART119')
plt.ylabel('Measure of Awesomeness')

# %%
def func_b(x):
    return .02 *np.exp(x)

# %%
y_b = func_b(x)

# %%
plt.plot(x,y_b)
plt.xlim(0,2*np.pi)
plt.ylim(-1,10)

# %%
y_c = 0.25 * x**2 + .1 * np.sin(10*x)

# %%
plt.plot(x,y_c)
plt.xlim(0,2*np.pi)
plt.ylim(-1,10)

# %%
plt.plot(x,y_a)
plt.plot(x,y_b)
plt.plot(x,y_c)
plt.xlim(0,2*np.pi)
plt.ylim(-1,10)
plt.xlabel('Time in ASTR/EART119')
plt.ylabel('Measure of Awesomeness')
# Out:
# Text(0, 0.5, 'Measure of Awesomeness')
